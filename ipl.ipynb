# %% [markdown]
# # IPL PROJECT

# %%
#import liabrary
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read dataset
df = pd.read_csv("C:\\Users\\Happy\\Downloads\\Players_Info_2024.csv")
df.head(10)
# Out:
#             Player Name Team Name Player Nationality Date of Birth  \
# 0              MS Dhoni       CSK             Indian      7-Jul-81
# 1          Devon Conway       CSK      South African      8-Jul-91
# 2       Ruturaj Gaikwad       CSK             Indian     31-Jan-97
# 3        Ajinkya Rahane       CSK             Indian      6-Jun-88
# 4         Shaik Rasheed       CSK             Indian     24-Sep-04
# 5          Sameer Rizvi       CSK             Indian      6-Dec-03
# 6  Avanish Rao Aravelly       CSK             Indian      2-Jun-05
# 7       Ravindra Jadeja       CSK             Indian      6-Dec-88
# 8      Mitchell Santner       CSK      New Zealander      5-Feb-92
# 9             Moeen Ali       CSK            English     18-Jun-87
#
#            Player Role  IPL Debut  \
# 0  Wicketkeeper Batter     2008.0
# 1  Wicketkeeper Batter     2022.0
# 2               Batter     2020.0
# 3     Top order Batter     2008.0
# 4               Batter        NaN
# ...

# %%
#check info of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player Name         245 non-null    object
#  1   Team Name           245 non-null    object
#  2   Player Nationality  245 non-null    object
#  3   Date of Birth       244 non-null    object
#  4   Player Role         245 non-null    object
#  5   IPL Debut           197 non-null    float64
#  6   About               245 non-null    object
#  7   Batting Style       245 non-null    object
#  8   Bowling Style       245 non-null    object
#  9   Player Salary       245 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 19.3+ KB

# %%
#check total number of null in ipl debut column
#we saw this in information just before
len(df["IPL Debut"][df["IPL Debut"].isnull()])
# Out:
# 48

# %%
#242th row with null value in ipl debut
df.iloc[242 ]
# Out:
# Player Name                                               Sakib Hussain
# Team Name                                                           KKR
# Player Nationality                                               Indian
# Date of Birth                                                 14-Dec-04
# Player Role                                                      Bowler
# IPL Debut                                                           NaN
# About                 Sakib Al Hasan is a prominent all-rounder from...
# Batting Style                                            Right hand Bat
# Bowling Style                                          Right arm Medium
# Player Salary                                      Salary not available
# Name: 242, dtype: object

# %%
#4th row with null value in ipl debut

df.loc[4:,("IPL Debut")]
# Out:
# 4         NaN
# 5         NaN
# 6      2023.0
# 7      2008.0
# 8      2019.0
#         ...
# 240    2018.0
# 241       NaN
# 242       NaN
# 243    2014.0
# 244    2021.0
# Name: IPL Debut, Length: 241, dtype: float64

# %%
df.loc[(4,"IPL Debut")]
# Out:
# nan

# %%
df.iloc[(4)]
# Out:
# Player Name                                               Shaik Rasheed
# Team Name                                                           CSK
# Player Nationality                                               Indian
# Date of Birth                                                 24-Sep-04
# Player Role                                                      Batter
# IPL Debut                                                           NaN
# About                 Sure! Shikhar Dhawan is an Indian cricketer wh...
# Batting Style                                            Right hand Bat
# Bowling Style                                                  Legbreak
# Player Salary                                        ₹20lakh(US$25,000)
# Name: 4, dtype: object

# %%
#all null values row or index in ipl debut column
df["IPL Debut"][df["IPL Debut"].isnull()]
# Out:
# 4     NaN
# 5     NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 30    NaN
# 31    NaN
# 35    NaN
# 39    NaN
# 41    NaN
# 44    NaN
# 87    NaN
# 89    NaN
# 105   NaN
# 108   NaN
# 113   NaN
# 125   NaN
# 127   NaN
# 128   NaN
# 129   NaN
# 130   NaN
# 136   NaN
# 148   NaN
# 149   NaN
# 150   NaN
# 155   NaN
# 156   NaN
# 162   NaN
# 170   NaN
# 171   NaN
# 173   NaN
# 174   NaN
# 176   NaN
# 185   NaN
# 192   NaN
# 193   NaN
# 200   NaN
# 206   NaN
# 207   NaN
# 215   NaN
# 223   NaN
# 233   NaN
# 234   NaN
# 237   NaN
# 238   NaN
# 239   NaN
# 241   NaN
# 242   NaN
# Name: IPL Debut, dtype: float64

# %%
#ipl debul null values with all data
df[df["IPL Debut"].isnull()]
# Out:
#                  Player Name Team Name Player Nationality Date of Birth  \
# 4              Shaik Rasheed       CSK             Indian     24-Sep-04
# 5               Sameer Rizvi       CSK             Indian      6-Dec-03
# 11            Nishant Sindhu       CSK             Indian      9-Apr-04
# 12               Ajay Mandal       CSK             Indian     25-Feb-96
# 13           Rachin Ravindra       CSK        New Zealand     18-Nov-99
# 30                 Shai Hope        DC        West Indies     10-Nov-93
# 31           Swastik Chikara        DC             Indian     15-Sep-04
# 35            Kumar Kushagra        DC             Indian     23-Oct-04
# 39               Sumit Kumar        DC             Indian     12-Dec-95
# 41              Vicky Ostwal        DC             Indian      1-Sep-02
# 44        Jake Fraser-McGurk        DC         Australian           NaN
# 87                 Phil Salt       KKR            England     28-Aug-96
# ...

# %%
df
# Out:
#              Player Name Team Name Player Nationality Date of Birth  \
# 0               MS Dhoni       CSK             Indian      7-Jul-81
# 1           Devon Conway       CSK      South African      8-Jul-91
# 2        Ruturaj Gaikwad       CSK             Indian     31-Jan-97
# 3         Ajinkya Rahane       CSK             Indian      6-Jun-88
# 4          Shaik Rasheed       CSK             Indian     24-Sep-04
# ..                   ...       ...                ...           ...
# 240     Mujeeb Ur Rahman       KKR             Afghan     28-Mar-01
# 241  Dushmantha Chameera       KKR         Sri Lankan     11-Jan-92
# 242        Sakib Hussain       KKR             Indian     14-Dec-04
# 243       Mitchell Starc       KKR         Australian     30-Jan-90
# 244      Chetan Sakariya       KKR             Indian     28-Feb-98
#
#              Player Role  IPL Debut  \
# 0    Wicketkeeper Batter     2008.0
# 1    Wicketkeeper Batter     2022.0
# 2                 Batter     2020.0
# ...

# %% [markdown]
# ## There are many player in 2024 season they not  debut or yet  debut in ipl so far but we assum that all fanchise are make mind to gave change to all player altleat one in 14 matches
# ## Fill with the 2024 debut

# %%
df["IPL Debut"] =df["IPL Debut"].replace(2024.0,np.NaN)

# %%
df = df.replace(np.nan,2024.0)

# %%
df
# Out:
#              Player Name Team Name Player Nationality Date of Birth  \
# 0               MS Dhoni       CSK             Indian      7-Jul-81
# 1           Devon Conway       CSK      South African      8-Jul-91
# 2        Ruturaj Gaikwad       CSK             Indian     31-Jan-97
# 3         Ajinkya Rahane       CSK             Indian      6-Jun-88
# 4          Shaik Rasheed       CSK             Indian     24-Sep-04
# ..                   ...       ...                ...           ...
# 240     Mujeeb Ur Rahman       KKR             Afghan     28-Mar-01
# 241  Dushmantha Chameera       KKR         Sri Lankan     11-Jan-92
# 242        Sakib Hussain       KKR             Indian     14-Dec-04
# 243       Mitchell Starc       KKR         Australian     30-Jan-90
# 244      Chetan Sakariya       KKR             Indian     28-Feb-98
#
#              Player Role  IPL Debut  \
# 0    Wicketkeeper Batter     2008.0
# 1    Wicketkeeper Batter     2022.0
# 2                 Batter     2020.0
# ...

# %%
#information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player Name         245 non-null    object
#  1   Team Name           245 non-null    object
#  2   Player Nationality  245 non-null    object
#  3   Date of Birth       245 non-null    object
#  4   Player Role         245 non-null    object
#  5   IPL Debut           245 non-null    float64
#  6   About               245 non-null    object
#  7   Batting Style       245 non-null    object
#  8   Bowling Style       245 non-null    object
#  9   Player Salary       245 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 19.3+ KB

# %%
#all different values in player salary
df["Player Salary"].unique()
# Out:
# array(['₹12crore(US$1.5\xa0million)', '₹1crore(US$130,000)',
#        '₹6crore(US$750,000)', '₹50lakh(US$63,000)', '₹20lakh(US$25,000)',
#        '840', 'Salary not available', '₹16crore(US$2.0\xa0million)',
#        '₹1.9crore(US$240,000)', '₹8crore(US$1.0\xa0million)',
#        '₹4crore(US$500,000)', '₹60lakh(US$75,000)', '180', '400', '1400',
#        '₹1.5crore(US$190,000)', '₹14crore(US$1.8\xa0million)',
#        '₹70lakh(US$88,000)', '₹2crore(US$250,000)',
#        '₹1.2crore(US$150,000)', '₹6.25crore(US$780,000)', '20', '720',
#        '50', '₹65lakh(US$81,000)', '₹6.5crore(US$810,000)',
#        '₹5.25crore(US$660,000)', '₹5.50crore(US$690,000)',
#        '₹15crore(US$1.9\xa0million)', '₹2.6crore(US$330,000)',
#        '₹3crore(US$380,000)', '₹7crore(US$880,000)',
#        '₹2.4crore(US$300,000)', '₹1.7crore(US$210,000)',
#        '₹9crore(US$1.1\xa0million)', '640', '₹1.4crore(US$180,000)',
#        '1150', '₹30lakh(US$38,000)', '500',
# ...

# %% [markdown]
# ### player salary shows is in object datatype

# %%
df["Player Salary"]=df["Player Salary"].replace('₹12crore(US$1.5\xa0million)','1200')
df["Player Salary"]=df["Player Salary"].replace('₹1crore(US$130,000)','100')
df["Player Salary"]=df["Player Salary"].replace('₹6crore(US$750,000)','600')
df["Player Salary"]=df["Player Salary"].replace('₹50lakh(US$63,000)','50')
df["Player Salary"]=df["Player Salary"].replace('₹20lakh(US$25,000)','20')
df["Player Salary"]=df["Player Salary"].replace('Salary not available','0')
df["Player Salary"]=df["Player Salary"].replace('₹16crore(US$2.0\xa0million)','1600')
df["Player Salary"]=df["Player Salary"].replace('₹1.9crore(US$240,000)','190')
df["Player Salary"]=df["Player Salary"].replace('₹8crore(US$1.0\xa0million)','800')
df["Player Salary"]=df["Player Salary"].replace( '₹4crore(US$500,000)','400')
df["Player Salary"]=df["Player Salary"].replace( '₹60lakh(US$75,000)','60')
df["Player Salary"]=df["Player Salary"].replace('₹1.5crore(US$190,000)','150')
df["Player Salary"]=df["Player Salary"].replace('₹14crore(US$1.8\xa0million)','1400')
df["Player Salary"]=df["Player Salary"].replace('₹70lakh(US$88,000)','70')
df["Player Salary"]=df["Player Salary"].replace('₹2crore(US$250,000)','200')
df["Player Salary"]=df["Player Salary"].replace('₹1.2crore(US$150,000)','120')
df["Player Salary"]=df["Player Salary"].replace('₹6.25crore(US$780,000)','625')
df["Player Salary"]=df["Player Salary"].replace('₹65lakh(US$81,000)','65')
df["Player Salary"]=df["Player Salary"].replace( '₹6.5crore(US$810,000)','650')
df["Player Salary"]=df["Player Salary"].replace('₹5.25crore(US$660,000)','525')
df["Player Salary"]=df["Player Salary"].replace( '₹5.50crore(US$690,000)','550')
df["Player Salary"]=df["Player Salary"].replace('₹15crore(US$1.9\xa0million)','1500')
df["Player Salary"]=df["Player Salary"].replace('₹2.6crore(US$330,000)','260')
df["Player Salary"]=df["Player Salary"].replace('₹3crore(US$380,000)','300')
df["Player Salary"]=df["Player Salary"].replace('₹7crore(US$880,000)','700')
df["Player Salary"]=df["Player Salary"].replace('₹2.4crore(US$300,000)','240')
df["Player Salary"]=df["Player Salary"].replace('₹1.7crore(US$210,000)','170')
df["Player Salary"]=df["Player Salary"].replace('₹9crore(US$1.1\xa0million)','900')
df["Player Salary"]=df["Player Salary"].replace('₹1.4crore(US$180,000)','140')
df["Player Salary"]=df["Player Salary"].replace('₹30lakh(US$38,000)','30')
df["Player Salary"]=df["Player Salary"].replace('₹12.25crore(US$1.5\xa0million)','1225')
df["Player Salary"]=df["Player Salary"].replace('₹10crore(US$1.3\xa0million)','1000')
df["Player Salary"]=df["Player Salary"].replace('₹17crore(US$2.1\xa0million)','1700')
df["Player Salary"]=df["Player Salary"].replace('₹7.75lakh(US$9,700)','7.75')

# %%
df["Player Salary"].unique()
# Out:
# array(['1200', '100', '600', '50', '20', '840', '0', '1600', '190', '800',
#        '400', '60', '180', '1400', '150', '70', '200', '120', '625',
#        '720', '65', '650', '525', '550', '1500', '260', '300', '700',
#        '240', '170', '900', '640', '140', '1150', '30', '500', '1225',
#        '₹55lakh(US$69,000)', '1000', '580', '1700', '7.75',
#        '₹6.75crore(US$850,000)', '₹5.75crore(US$720,000)',
#        '₹90lakh(US$110,000)', '₹8.25crore(US$1.0\xa0million)',
#        '₹11crore(US$1.4\xa0million)', '₹45lakh(US$56,000)',
#        '₹15.25crore(US$1.9\xa0million)', '₹75lakh(US$94,000)',
#        '₹4.60crore(US$580,000)', '₹11.5crore(US$1.4\xa0million)',
#        '₹4.6crore(US$580,000)', '420', '₹18.5crore(US$2.3\xa0million)',
#        '₹3.80crore(US$480,000)', '₹9.25crore(US$1.2\xa0million)', '1175',
#        '₹8.5crore(US$1.1\xa0million)', '740', '40', '₹5crore(US$630,000)',
#        '₹2.60crore(US$330,000)', '₹3.4crore(US$430,000)',
# ...

# %%
df["Player Salary"] =df["Player Salary"].replace('₹5.75crore(US$720,000)','575')
df["Player Salary"] =df["Player Salary"].replace('₹90lakh(US$110,000)','90')
df["Player Salary"] =df["Player Salary"].replace('₹8.25crore(US$1.0\xa0million)','825')
df["Player Salary"] =df["Player Salary"].replace('₹11crore(US$1.4\xa0million)','1100')
df["Player Salary"] =df["Player Salary"].replace('₹45lakh(US$56,000)','45')
df["Player Salary"] =df["Player Salary"].replace('₹15.25crore(US$1.9\xa0million)','1525')
df["Player Salary"] =df["Player Salary"].replace('₹75lakh(US$94,000)','75')
df["Player Salary"] =df["Player Salary"].replace('₹4.60crore(US$580,000)','460')
df["Player Salary"] =df["Player Salary"].replace('₹11.5crore(US$1.4\xa0million)','1150')
df["Player Salary"] =df["Player Salary"].replace('₹4.6crore(US$580,000)','460')
df["Player Salary"] =df["Player Salary"].replace('₹18.5crore(US$2.3\xa0million)','1850')
df["Player Salary"] =df["Player Salary"].replace('₹3.80crore(US$480,000)','380')
df["Player Salary"] =df["Player Salary"].replace('₹9.25crore(US$1.2\xa0million)','925')
df["Player Salary"] =df["Player Salary"].replace('₹8.5crore(US$1.1\xa0million)','850')
df["Player Salary"] =df["Player Salary"].replace('₹5crore(US$630,000)','500')
df["Player Salary"] =df["Player Salary"].replace('₹2.60crore(US$330,000)','260')
df["Player Salary"] =df["Player Salary"].replace('₹3.4crore(US$430,000)','340')
df["Player Salary"] =df["Player Salary"].replace('₹5.5crore(US$690,000)','550')
df["Player Salary"] =df["Player Salary"].replace('₹3.2crore(US$400,000)','320')
df["Player Salary"] =df["Player Salary"].replace('₹95lakh(US$120,000)','95')
df["Player Salary"] =df["Player Salary"].replace('₹17.5crore(US$2.2\xa0million)','1750')
df["Player Salary"] =df["Player Salary"].replace('₹4.2crore(US$530,000)','420')
df["Player Salary"] =df["Player Salary"].replace('₹25lakh(US$31,000)','250')
df["Player Salary"] =df["Player Salary"].replace('₹4.2crore(US$530,000)','420')
df["Player Salary"] =df["Player Salary"].replace('₹8.75crore(US$1.1\xa0million)','875')
df["Player Salary"] =df["Player Salary"].replace('₹1.8crore(US$230,000)','180')
df["Player Salary"] =df["Player Salary"].replace('₹6.75crore(US$850,000)','675')
df["Player Salary"] =df["Player Salary"].replace('₹55lakh(US$69,000)',"55")
#df["Player Salary"] =df["Player Salary"].replace("₹55lakh(US$69,000)","55")
#f["Player Salary"] =df["Player Salary"].replace("₹55lakh(US$69,000)","55")

# %%
df["Player Salary"].unique()
# Out:
# array(['1200', '100', '600', '50', '20', '840', '0', '1600', '190', '800',
#        '400', '60', '180', '1400', '150', '70', '200', '120', '625',
#        '720', '65', '650', '525', '550', '1500', '260', '300', '700',
#        '240', '170', '900', '640', '140', '1150', '30', '500', '1225',
#        '55', '1000', '580', '1700', '7.75', '675', '575', '90', '825',
#        '1100', '45', '1525', '75', '460', '420', '1850', '380', '925',
#        '1175', '850', '740', '40', '340', '320', '95', '1750', '250',
#        '680', '875', '160', '2050', '220', '2475'], dtype=object)

# %%
#df["Player Salary"] =pd.to_numeric(df["player Salary"])

# %% [markdown]
# ### Feature engeering convert player salary date type object to numeric

# %%
df["Player Salary"] =pd.to_numeric(df["Player Salary"])

# %%
df["Player Salary"].unique()
# Out:
# array(['1200', '100', '600', '50', '20', '840', '0', '1600', '190', '800',
#        '400', '60', '180', '1400', '150', '70', '200', '120', '625',
#        '720', '65', '650', '525', '550', '1500', '260', '300', '700',
#        '240', '170', '900', '640', '140', '1150', '30', '500', '1225',
#        '55', '1000', '580', '1700', '7.75', '675', '575', '90', '825',
#        '1100', '45', '1525', '75', '460', '420', '1850', '380', '925',
#        '1175', '850', '740', '40', '340', '320', '95', '1750', '250',
#        '680', '875', '160', '2050', '220', '2475'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player Name         245 non-null    object
#  1   Team Name           245 non-null    object
#  2   Player Nationality  245 non-null    object
#  3   Date of Birth       245 non-null    object
#  4   Player Role         245 non-null    object
#  5   IPL Debut           245 non-null    float64
#  6   About               245 non-null    object
#  7   Batting Style       245 non-null    object
#  8   Bowling Style       245 non-null    object
#  9   Player Salary       245 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 19.3+ KB

# %% [markdown]
# # Feature engeering convert player salary date type object to numeric

# %%
df["Date of Birth"] =pd.to_datetime(df["Date of Birth"])

# %%
df["Date of Birth"].unique()
# Out:
# array(['1981-07-07T00:00:00.000000000', '1991-07-08T00:00:00.000000000',
#        '1997-01-31T00:00:00.000000000', '1988-06-06T00:00:00.000000000',
#        '2004-09-24T00:00:00.000000000', '2003-12-06T00:00:00.000000000',
#        '2005-06-02T00:00:00.000000000', '1988-12-06T00:00:00.000000000',
#        '1992-02-05T00:00:00.000000000', '1987-06-18T00:00:00.000000000',
#        '1993-06-26T00:00:00.000000000', '2004-04-09T00:00:00.000000000',
#        '1996-02-25T00:00:00.000000000', '1999-11-18T00:00:00.000000000',
#        '1991-10-16T00:00:00.000000000', '1991-05-20T00:00:00.000000000',
#        '2002-11-10T00:00:00.000000000', '1992-08-07T00:00:00.000000000',
#        '2000-08-01T00:00:00.000000000', '1996-07-06T00:00:00.000000000',
#        '1995-09-06T00:00:00.000000000', '1992-10-15T00:00:00.000000000',
#        '1998-01-17T00:00:00.000000000', '1995-05-15T00:00:00.000000000',
#        '2002-12-18T00:00:00.000000000', '1997-10-04T00:00:00.000000000',
# ...

# %%
df["Date of Birth"] =pd.to_datetime(df["Date of Birth"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player Name         245 non-null    object
#  1   Team Name           245 non-null    object
#  2   Player Nationality  245 non-null    object
#  3   Date of Birth       245 non-null    datetime64[ns]
#  4   Player Role         245 non-null    object
#  5   IPL Debut           245 non-null    float64
#  6   About               245 non-null    object
#  7   Batting Style       245 non-null    object
#  8   Bowling Style       245 non-null    object
#  9   Player Salary       245 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 19.3+ KB

# %% [markdown]
# ### data visualization with multiple plot use python liabray sesaborn and matplotlib

# %%
sns.histplot(df["Date of Birth"])
# Out:
# <Axes: xlabel='Date of Birth', ylabel='Count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x="IPL Debut" ,
              data =df,
              order=df["IPL Debut"].value_counts().index.sort_values())
plt.xlabel("debut year")ssssss
plt.ylabel("no .of debut in year ")
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x="Team Name" ,
              data =df,
              order=df["Team Name"].value_counts().index.sort_values())
plt.xlabel("debut year")
plt.ylabel("no .of debut in year ")
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x="Player Role" ,
              data =df,
              order=df["Player Role"].value_counts().index.sort_values())
plt.xlabel("debut year")
plt.ylabel("no .of debut in year ")
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x="Date of Birth" ,
              data =df,
              order=df["Date of Birth"].value_counts().index.sort_values())
plt.xlabel("debut year")
plt.ylabel("no .of debut in year ")
plt.show()

# %%
df
# Out:
#              Player Name Team Name Player Nationality Date of Birth  \
# 0               MS Dhoni       CSK             Indian    1981-07-07
# 1           Devon Conway       CSK      South African    1991-07-08
# 2        Ruturaj Gaikwad       CSK             Indian    1997-01-31
# 3         Ajinkya Rahane       CSK             Indian    1988-06-06
# 4          Shaik Rasheed       CSK             Indian    2004-09-24
# ..                   ...       ...                ...           ...
# 240     Mujeeb Ur Rahman       KKR             Afghan    2001-03-28
# 241  Dushmantha Chameera       KKR         Sri Lankan    1992-01-11
# 242        Sakib Hussain       KKR             Indian    2004-12-14
# 243       Mitchell Starc       KKR         Australian    1990-01-30
# 244      Chetan Sakariya       KKR             Indian    1998-02-28
#
#              Player Role  IPL Debut  \
# 0    Wicketkeeper Batter     2008.0
# 1    Wicketkeeper Batter     2022.0
# 2                 Batter     2020.0
# ...

# %% [markdown]
# # Connect to sql

# %% [markdown]
# #### conecting and close

# %%
import mysql.connector

# Connect to MySQL
cnx = mysql.connector.connect(
    host="root",
    user="localhost",
    password="vishal",
    database="python_connect"
)

# Create a cursor
cursor = cnx.cursor()

# Example MySQL query
query = "use pyth"

# Execute the query
cursor.execute(query)

# Fetch all rows
result = cursor.fetchall()

# Now 'result' contains the data from MySQL, you can process it as needed

# Don't forget to close cursor and connection
cursor.close()
cnx.close()

# %%
from sqlalchemy import create_engine

# Connect to MySQL using SQLAlchemy
engine = create_engine("mysql+mysqlconnector://root:vishal@localhost:3306/python_connect")

# Write the DataFrame to MySQL
dff.to_sql('dff', con=engine, if_exists='replace', index=False)

# Now you can run SQL queries against the MySQL database using pandas
query = "select max(Player_salary_in_lakh),Team_name from dff group by Team_Name "
result_df = pd.read_sql_query(query, engine)

# %%
import mysql.connector

# Establishing the connection
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="vishal",
    database="practise"
)

# %%
cursor = connection.cursor()

# %%
cursor.execute("show tables")

# %%
myresult = cursor.fetchall()

for x in myresult:
    print(x)
# Out:
# ('countries',)
# ('customer',)
# ('customers',)
# ('data',)
# ('departments',)
# ('employees',)
# ('items',)
# ('itemss',)
# ('nobel_prizes',)
# ('orders',)
# ('salesman',)
# ('salesmen',)
# ('testtable',)

# %%
def mysql(s):
    cursor = connection.cursor()
    cursor.execute(input("enetr mydql code"))
    myresult = cursor.fetchall()
    return(myresult)

# %%
cursor.close()
connection.close()

# %% [markdown]
# ####  change column name becouse of sql create problems with space

# %%
dff = pd.read_csv("C:\\Users\\Happy\\Downloads\\Players_Info_2024.csv",names=
                ["Player_Name","Team_Name","Player_Nationality","DOB","Role" ,"Debut_year","About","Batting_Style","Bowling_style","salary"],header=0)

# %%
from sqlalchemy import create_engine

# Connect to MySQL using SQLAlchemy
engine = create_engine("mysql+mysqlconnector://root:vishal@localhost:3306/python_connect")

# Write the DataFrame to MySQL
dff.to_sql('dff', con=engine, if_exists='replace', index=False)

# Now you can run SQL queries against the MySQL database using pandas
query = "select max(salary),Team_Name from dff group by Team_Name "
result_df = pd.read_sql_query(query, engine)

# %% [markdown]
# ### Each team higtest salary player

# %%
result_df
# Out:
#    max(salary) Team_Name
# 0       1600.0       CSK
# 1       1600.0        DC
# 2       1600.0        MI
# 3       1500.0        GT
# 4       1700.0       LSG
# 5       1750.0       RCB
# 6       2475.0       KKR
# 7       1850.0      PBKS
# 8       1400.0        RR
# 9       2050.0       SRH

# %%
# df

# %% [markdown]
# ### Top 10 highest paid player

# %%
query = "select salary,Player_name from dff order by salary desc limit 10"
result_df = pd.read_sql_query(query, engine)

# %%
result_df
# Out:
#    salary      Player_name
# 0  2475.0   Mitchell Starc
# 1  2050.0      Pat Cummins
# 2  1850.0       Sam Curran
# 3  1750.0    Cameron Green
# 4  1700.0         KL Rahul
# 5  1600.0  Nicholas Pooran
# 6  1600.0     Rishabh Pant
# 7  1600.0     Rohit Sharma
# 8  1600.0  Ravindra Jadeja
# 9  1525.0     Ishan Kishan

# %%
dff =df

# %%
dff =df

# %%
dff.columns = ["Player_Name","Team_Name","Player_Nationality","DOB","Role" ,"Debut_year","About","Batting_Style","Bowling_style","salary"]

# %% [markdown]
# ### lower paid player

# %%
query = "select salary,Player_name from dff where salary > 0 order by salary asc limit 10"
result_df = pd.read_sql_query(query, engine)

# %%
result_df
# Out:
#    salary          Player_name
# 0    7.75     Devdutt Padikkal
# 1   20.00     Anmolpreet Singh
# 2   20.00     Darshan Nalkande
# 3   20.00        Shreyas Gopal
# 4   20.00          Kuldeep Sen
# 5   20.00        Shaik Rasheed
# 6   20.00       Manoj Bhandage
# 7   20.00        Atharva Taide
# 8   20.00  Kunal Singh Rathore
# 9   20.00          Dhruv Jurel

# %%
query = "select player_name ,debut_year,role,salary from dff where debut_year=2022"
result_df = pd.read_sql_query(query, engine)

# %%
result_df
# Out:
#             player_name  debut_year                 role  salary
# 0          Devon Conway      2022.0  Wicketkeeper Batter   100.0
# 1        Daryl Mitchell      2022.0   Batting Allrounder  1400.0
# 2    Maheesh Theekshana      2022.0               Bowler    70.0
# 3      Mukesh Choudhary      2022.0               Bowler    20.0
# 4      Prashant Solanki      2022.0               Bowler   120.0
# 5       Simarjeet Singh      2022.0               Bowler    20.0
# 6   Matheesha Pathirana      2022.0               Bowler    20.0
# 7        Tristan Stubbs      2022.0  Wicketkeeper Batter    50.0
# 8       Abhinav Manohar      2022.0   Batting Allrounder   260.0
# 9      B. Sai Sudharsan      2022.0     Top order Batter     0.0
# 10     Darshan Nalkande      2022.0               Bowler    20.0
# 11          Sai Kishore      2022.0               Bowler     0.0
# 12           Yash Dayal      2022.0               Bowler   500.0
# ...

# %%
query = "select player_name ,debut_year,role,salary from dff where debut_year=2023"
result_df = pd.read_sql_query(query, engine)

# %%
result_df
# Out:
#                player_name  debut_year                 role  salary
# 0     Avanish Rao Aravelly      2023.0  Wicketkeeper Batter     0.0
# 1   Rajvardhan Hangargekar      2023.0   Bowling Allrounder   150.0
# 2               Yash Dhull      2023.0     Top order Batter    50.0
# 3            Abishek Porel      2023.0  Wicketkeeper Batter    20.0
# 4              Harry Brook      2023.0               Batter   400.0
# 5             Mukesh Kumar      2023.0               Bowler   550.0
# 6               Noor Ahmad      2023.0               Bowler    30.0
# 7            Joshua Little      2023.0               Bowler     0.0
# 8       Rahmanullah Gurbaz      2023.0  Wicketkeeper Batter    50.0
# 9            Suyash Sharma      2023.0               Bowler    20.0
# 10             Kyle Mayers      2023.0   Batting Allrounder    50.0
# 11             Arshad Khan      2023.0               Bowler    20.0
# 12           Yudhvir Singh      2023.0               Bowler    20.0
# ...
